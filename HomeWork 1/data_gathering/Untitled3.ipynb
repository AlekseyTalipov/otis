# %%
# %time %run -i ./gathering.py gather
# Out:
# INFO:__main__:Work started
# INFO:__main__:gather
# C:\Program Files\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Program Files\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# INFO:__main__:work ended
# Wall time: 1.22 s

# %%
ls
# Out:
#  Том в устройстве C имеет метку ssd system
#  Серийный номер тома: 3868-D050
#
#  Содержимое папки C:\Users\gat\Documents\обучение Otis\data_gathering-19469-333527\data_gathering
#
# 03.09.2018  00:12    <DIR>          .
# 03.09.2018  00:12    <DIR>          ..
# 02.09.2018  22:44    <DIR>          .ipynb_checkpoints
# 02.09.2018  00:46    <DIR>          .vscode
# 23.08.2018  00:25                 0 __init__.py
# 29.08.2018  23:48    <DIR>          __pycache__
# 02.09.2018  23:23             7 652 gathering.py
# 29.08.2018  23:53    <DIR>          parsers
# 29.08.2018  23:54            70 273 scrapped_data.txt
# 01.09.2018  23:59    <DIR>          scrappers
# 23.08.2018  00:26    <DIR>          storages
# 02.09.2018  23:56            19 354 Untitled.ipynb
# 02.09.2018  22:42             2 307 Untitled1.ipynb
# 02.09.2018  22:44             2 459 Untitled2.ipynb
# 03.09.2018  00:12            15 770 Untitled3.ipynb
#                7 файлов        117 815 байт
#                8 папок  59 040 043 008 байт свободно

# %%
import logging
import requests
import robobrowser
import pandas as pd

from robobrowser import RoboBrowser
from robobrowser.forms.form import Form, Payload, fields, _parse_fields


logger = logging.getLogger(__name__)


class Scrapper(object):
    def __init__(self, skip_objects=None):
        self.skip_objects = skip_objects

    def scrap_process(self, storage):

        # You can iterate over ids, or get list of objects
        # from any API, or iterate throught pages of any site
        # Do not forget to skip already gathered data
        # Here is an example for you
        #     'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
        #     'Accept' : 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        #     'Accept-Language' : 'ru-RU,ru;q=0.8,en-US;q=0.6,en;q=0.4',
        #     'Accept-Encoding' : 'gzip, deflate, sdch'}
        def auth():
            LoginForm=q.get_form(id="aspnetForm")

            LoginForm['ctl00$ctl00$ModalLogin1$LoginTextBox'].value= 'avtostrada'
            LoginForm['ctl00$ctl00$ModalLogin1$PasswordTextBox'].value = '5ed8f5'

            LoginForm.add_field(robobrowser.forms.fields.Input('\<input name="__EVENTARGUMENT" value="" \/\>'))
            LoginForm.add_field(robobrowser.forms.fields.Input('\<input name="__EVENTTARGET" value="ctl00$ctl00$ModalLogin1$ButtonFilter" \/\>'))

            q.submit_form(LoginForm, submit=LoginForm['ctl00$ctl00$ModalLogin1$ButtonFilter'])

           
        def get_download_url(link):
            d=link.get('href')
            return 'http://brokenstone.ru/'+ d
            #content=q.session.get(durl)
        
        def save_download(durl):
            file1=q.session.get(durl)
            #if file1.headers['Content-Type'] == 'application/octet-stream':
            nameFile=(file1.headers['Content-Disposition']).split('=')
            xls_file='./{0}'.format(nameFile[1])
            logger.info(xls_file)
            with open(xls_file, "wb") as output:
                output.write(file1.content)
            return nameFile[1]

            #else:
            #    logger.error(u'Какая то хрень')

        url = storage
        logger.info("Начинаем загрузку")
        q=RoboBrowser()
        q.open(url)
        response = q.state

        if not response.response.ok:
            logger.error(response.response.text)
            # then continue process, or retry, or fix your code
        else:
            auth()
            a = q.get_links('Поставки по жд за')
            durls = list(map(get_download_url, a))
            logger.info(durls)
            #d=a[1].get('href')
            #durl='http://brokenstone.ru/'+ d
            #content=map(q.session.get, durls)

            downloadFales = list(map(save_download, durls))

            logger.info(downloadFales)

# %%
import logging

import sys

from scrappers.scrapper import Scrapper
from storages.file_storage import FileStorage

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


SCRAPPED_FILE = 'http://brokenstone.ru/supplyfileexport.aspx'
TABLE_FORMAT_FILE = 'data.csv'


def gather_process():
    logger.info("gather")
    #storage = FileStorage(SCRAPPED_FILE)

    # You can also pass a storage
    scrapper = Scrapper()
    scrapper.scrap_process(SCRAPPED_FILE)


def convert_data_to_table_format():
    logger.info("transform")

    # Your code here
    # transform gathered data from txt file to pandas DataFrame and save as csv
    pass


def stats_of_data():
    logger.info("stats")

    # Your code here
    # Load pandas DataFrame and print to stdout different statistics about the data.
    # Try to think about the data and use not only describe and info.
    # Ask yourself what would you like to know about this data (most frequent word, or something else)


if __name__ == '__main__':
    """
    why main is so...?
    https://stackoverflow.com/questions/419163/what-does-if-name-main-do
    """
    logger.info("Work started")

    if sys.argv[1] == 'gather':
        gather_process()

    elif sys.argv[1] == 'transform':
        convert_data_to_table_format()

    elif sys.argv[1] == 'stats':
        stats_of_data()

    logger.info("work ended")
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\robobrowser\browser.py:40: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 40 of the file C:\Program Files\Anaconda3\lib\site-packages\robobrowser\browser.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   features=self.browser.parser,
# INFO:__main__:Work started
# INFO:__main__:work ended

# %%
gather_process()
# Out:
# INFO:__main__:gather
# C:\Program Files\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Program Files\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
#storage = FileStorage(SCRAPPED_FILE)
SCRAPPED_FILE = 'http://brokenstone.ru/supplyfileexport.aspx'
scrapper = Scrapper()
scrapper.scrap_process(SCRAPPED_FILE)

#scrapper.scrap_process(storage)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Program Files\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
ls
# Out:
#  Том в устройстве C имеет метку ssd system
#  Серийный номер тома: 3868-D050
#
#  Содержимое папки C:\Users\gat\Documents\обучение Otis\data_gathering-19469-333527\data_gathering
#
# 03.09.2018  00:05    <DIR>          .
# 03.09.2018  00:05    <DIR>          ..
# 02.09.2018  22:44    <DIR>          .ipynb_checkpoints
# 02.09.2018  00:46    <DIR>          .vscode
# 23.08.2018  00:25                 0 __init__.py
# 29.08.2018  23:48    <DIR>          __pycache__
# 02.09.2018  23:23             7 652 gathering.py
# 29.08.2018  23:53    <DIR>          parsers
# 03.09.2018  00:05         4 242 432 rzd_01_09_2018.xls
# 29.08.2018  23:54            70 273 scrapped_data.txt
# 01.09.2018  23:59    <DIR>          scrappers
# 23.08.2018  00:26    <DIR>          storages
# 02.09.2018  23:56            19 354 Untitled.ipynb
# 02.09.2018  22:42             2 307 Untitled1.ipynb
# 02.09.2018  22:44             2 459 Untitled2.ipynb
# 03.09.2018  00:04            19 892 Untitled3.ipynb
#                8 файлов      4 364 369 байт
#                8 папок  58 999 054 336 байт свободно

# %%
Scrapper.scrap_process(Scrapper,'http://brokenstone.ru/supplyfileexport.aspx')
# Out:
# INFO:scrappers.scrapper:Начинаем загрузку
# C:\Program Files\Anaconda3\lib\site-packages\robobrowser\browser.py:40: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 40 of the file C:\Program Files\Anaconda3\lib\site-packages\robobrowser\browser.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   features=self.browser.parser,
# INFO:scrappers.scrapper:['http://brokenstone.ru/Downloading.aspx?file=rzd_08_09_2018.xls&id=5545&act=supply', 'http://brokenstone.ru/Downloading.aspx?file=rzd_07_09_2018.xls&id=5544&act=supply', 'http://brokenstone.ru/Downloading.aspx?file=rzd_06_09_2018.xls&id=5540&act=supply', 'http://brokenstone.ru/Downloading.aspx?file=rzd_05_09_2018.xls&id=5538&act=supply', 'http://brokenstone.ru/Downloading.aspx?file=rzd_04_09_2018.xls&id=5536&act=supply', 'http://brokenstone.ru/Downloading.aspx?file=rzd_03_09_2018.xls&id=5534&act=supply', 'http://brokenstone.ru/Downloading.aspx?file=rzd_02_09_2018.xls&id=5532&act=supply', 'http://brokenstone.ru/Downloading.aspx?file=rzd_01_09_2018.xls&id=5530&act=supply']
# INFO:scrappers.scrapper:./rzd_08_09_2018.xls
# INFO:scrappers.scrapper:./rzd_07_09_2018.xls
# INFO:scrappers.scrapper:./rzd_06_09_2018.xls
# INFO:scrappers.scrapper:./rzd_05_09_2018.xls
# INFO:scrappers.scrapper:./rzd_04_09_2018.xls
# INFO:scrappers.scrapper:./rzd_03_09_2018.xls
# INFO:scrappers.scrapper:./rzd_02_09_2018.xls
# INFO:scrappers.scrapper:./rzd_01_09_2018.xls
# INFO:scrappers.scrapper:['rzd_08_09_2018.xls', 'rzd_07_09_2018.xls', 'rzd_06_09_2018.xls', 'rzd_05_09_2018.xls', 'rzd_04_09_2018.xls', 'rzd_03_09_2018.xls', 'rzd_02_09_2018.xls', 'rzd_01_09_2018.xls']

# %%
df=['rzd_08_09_2018.xls', 'rzd_07_09_2018.xls', 'rzd_06_09_2018.xls', 'rzd_05_09_2018.xls', 'rzd_04_09_2018.xls', 'rzd_03_09_2018.xls', 'rzd_02_09_2018.xls', 'rzd_01_09_2018.xls']

#dataframe=pd.read_excel(downloadFales[0])

# %%
dataframe=pd.concat(map(pd.read_excel, df))

# %%
dataframe.count()
# Out:
# Номер документа                             52066
# Дата оформления                                 0
# Дата отправления                            52066
# Плановая дата прибытия                      52066
# Факт дата прибытия                              0
# Дата раскредитовки                              0
# Вид перевозки                               52066
# Тип сообщения                               52066
# Вид сообщения                               52066
# Категория отправки                          52066
# Код груза                                   52066
# Наименование груза                          52066
# Класс груза                                 52066
# Группа груза                                52066
# Подгруппа груза                             52066
# Группа груза по оперативной номенклатуре    52066
# Группа груза по ЦО 21                       52066
# Группа груза по ГО6                         52066
# Код груза по ГНГ                            52066
# Груз по ГНГ                                 52066
# Груз ОКВЭД                                  52066
# Государство отправления                     52066
# Признак государства отправления             52066
# Дорога отправления                          52066
# Субъект РФ отправления                      52066
# Код станции отправления РФ                  52066
# Станция отправления РФ                      52066
# Признак станции отправления РФ              52066
# Признак погран перехода отправления РФ      52066
# Код станции отправления СНГ                 52066
#                                             ...
# Код исключительного тарифа (КИТ)            52066
# ДЗО код                                     52066
# Признак места расчета                       52066
# Признак зачета                              52066
# Признак доверителя                          52066
# Сумма скидки                                52066
# Пояс дальности                              52066
# Пояс дальности по прейскуранту 10-01        52066
# Признак тарифа                              52066
# Код валюты                                  52066
# Собственник вагона по ЕГРПО                 52066
# Арендатор вагона по ГВЦ                     52066
# ОКПО Арендатора                              6787
# ИНН Арендатора                               4748
# Признак аренды                              52066
# Арендатор по внутреннему справочнику            0
# Номер контейнера                            52066
# Тоннажность контейнера                      52066
# Номер вагона                                52066
# Вид подвижного состава                      52066
# Род вагона                                  52066
# Подрод вагона                               52066
# Усл тип вагона                              52066
# Модель вагона                               40472
# Дата постройки                              40472
# Парк вагонов                                40472
# Тип парка                                   52066
# Станция  приписки                           52066
# Признак вагонных перевозок                  52066
# Признак контейнерных перевозок              52066
# Length: 89, dtype: int64

# %%
dataframe.to_pickle('data.pkl')

# %%
df=pd.read_pickle('data.pkl')

# %%
df.to_csv("data.csv")

# %%
df.columns
# Out:
# Index(['Номер документа', 'Дата оформления', 'Дата отправления',
#        'Плановая дата прибытия', 'Факт дата прибытия', 'Дата раскредитовки',
#        'Вид перевозки', 'Тип сообщения', 'Вид сообщения', 'Категория отправки',
#        'Код груза', 'Наименование груза', 'Класс груза', 'Группа груза',
#        'Подгруппа груза', 'Группа груза по оперативной номенклатуре',
#        'Группа груза по ЦО 21', 'Группа груза по ГО6', 'Код груза по ГНГ',
#        'Груз по ГНГ', 'Груз ОКВЭД', 'Государство отправления',
#        'Признак государства отправления', 'Дорога отправления',
#        'Субъект РФ отправления', 'Код станции отправления РФ',
#        'Станция отправления РФ', 'Признак станции отправления РФ',
#        'Признак погран перехода отправления РФ', 'Код станции отправления СНГ',
#        'Станция отправления СНГ', 'Признак станции отправления СНГ',
#        'Принадлежность станции отправления СНГ',
#        'Признак погран перехода отправления СНГ',
#        'Грузоотправитель наим по ЕГРПО', 'Грузоотправитель жд код',
#        'Грузоотправитель ОКПО', 'Паром Усть-Луга - Балтийск',
#        'Государство назначения', 'Признак государства назначения',
#        'Дорога назначения', 'Субъект РФ назначения',
#        'Код станции назначения РФ', 'Станция назначения РФ',
#        'Признак станции назн РФ', 'Признак погран перехода назначения РФ',
#        'Код станции назначения СНГ', 'Станция назначения СНГ',
#        'Признак станции назначения СНГ',
#        'Принадлежность станции назначения СНГ',
#        'Признак погран перехода назначения СНГ',
#        'Грузополучатель наим по ЕГРПО', 'Грузополучатель жд код',
#        'Грузополучатель код ОКПО', 'Плательщик жд тарифа',
#        'Ваг*Км (тариф Расстояние)', 'Объем перевозок тонн',
#        'Объем перевозок кг', 'Провозная плата',
#        'Код исключительного тарифа (КИТ)', 'ДЗО код', 'Признак места расчета',
#        'Признак зачета', 'Признак доверителя', 'Сумма скидки',
#        'Пояс дальности', 'Пояс дальности по прейскуранту 10-01',
#        'Признак тарифа', 'Код валюты', 'Собственник вагона по ЕГРПО',
#        'Арендатор вагона по ГВЦ', 'ОКПО Арендатора', 'ИНН Арендатора',
#        'Признак аренды', 'Арендатор по внутреннему справочнику',
#        'Номер контейнера', 'Тоннажность контейнера', 'Номер вагона',
#        'Вид подвижного состава', 'Род вагона', 'Подрод вагона',
#        'Усл тип вагона', 'Модель вагона', 'Дата постройки', 'Парк вагонов',
#        'Тип парка', 'Станция  приписки', 'Признак вагонных перевозок',
#        'Признак контейнерных перевозок'],
#       dtype='object')

# %%
df.pivot_table('Объем перевозок тонн', ['Наименование груза', 'Субъект РФ отправления'] ,aggfunc='sum')
# Out:
#                                                              Объем перевозок тонн
# Наименование груза Субъект РФ отправления
# ГАББРО             Белгородская область                                        70
#                    Новосибирская область                                        7
# ГРАВИЙ             Забайкальский край                                          67
#                    Краснодарский край                                       16622
#                    Ленинградская область                                       69
#                    Ярославская область                                        823
# ИЗВЕСТНЯК Д/ФЛ     Вологодская область                                       4591
#                    Город Москва столица Российской Федераци                    29
#                    Кемеровская область                                      14917
#                    Липецкая область                                         16903
#                    Оренбургская область                                     10374
#                    Республика Башкортостан                                   3118
#                    Ростовская область                                        4592
#                    Свердловская область                                     36514
#                    Тульская область                                          4137
#                    Хабаровский край                                          2121
#                    Челябинская область                                      21658
# ИЗВЕСТНЯК М ПР     Белгородская область                                       126
#                    Владимирская область                                      4636
#                    Еврейская Автономная область                                71
#                    Калужская область                                         2469
#                    Ленинградская область                                      215
#                    Новгородская область                                       461
#                    Пермский край                                              625
#                    Псковская область                                          713
#                    Тульская область                                          2542
# ИЗВЕСТНЯК СТР      Город Москва столица Российской Федераци                    10
#                    Калининградская область                                   1198
#                    Кемеровская область                                       6653
#                    Новосибирская область                                      461
# ...                                                                           ...
# ЩЕБЕНЬ Д/БАЛ ЖП    Приморский край                                          16928
#                    Псковская область                                         8126
#                    Республика Башкортостан                                  29154
#                    Республика Бурятия                                       30891
#                    Республика Дагестан                                       1788
#                    Республика Калмыкия                                       8055
#                    Республика Карелия                                       53771
#                    Республика Коми                                          14448
#                    Республика Мордовия                                       2400
#                    Республика Северная Осетия-Алания                         1191
#                    Республика Татарстан (Татарстан)                         15149
#                    Ростовская область                                       40363
#                    Рязанская область                                         5280
#                    Самарская область                                        17447
#                    Саратовская область                                       8241
#                    Сахалинская область                                       2178
#                    Свердловская область                                     53782
#                    Смоленская область                                        6385
#                    Ставропольский край                                       1278
#                    Субъект РФ не определен                                    420
#                    Тверская область                                          3955
#                    Тульская область                                          3434
#                    Тюменская область                                        11226
#                    Удмуртская Республика                                     5735
#                    Ульяновская область                                       5540
#                    Хабаровский край                                          8543
#                    Ханты-Мансийский автономный округ (Тюмен                  7520
#                    Челябинская область                                      67394
#                    Чувашская Республика-Чаваш Республики                     4066
#                    Ярославская область                                       9822
#
# [250 rows x 1 columns]
